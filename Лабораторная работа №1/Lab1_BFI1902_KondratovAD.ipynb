# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БФИ1902 Кондратов А.Д.
# ## Задание №1

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## Задание №2

# %%
import random

m = int(input() or "50")
n = int(input() or "50")
min_limit = int(input() or "-250")
max_limit = int(input() or "1006")
new_array = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
        for j in range(n):
            print(new_array[i][j],end=' ')
        print("\n")
# Out:
# 5
# 7
#
#
# -108 -15 844 180 18 -227 988
#
# 914 -51 578 -49 -231 514 -51
#
# -129 788 -23 -191 147 417 819
#
# 729 159 -120 85 582 193 -12
#
# 416 -192 563 319 77 654 365

# %% [markdown]
# ## Задание №3

# %%
import random
from queue import PriorityQueue

# Сортировка выбором
# Проходим по элементам списка, меняя их местами с наименьшими элементами, которые идут после них по списку
# Лучшее-среднее-худшее время - n^2

def sel_sort(array):
    for i in range(len(array) - 1):
        m = i
        for j in range (i + 1, len(array)):
            if array[j] < array[m]:
                m = j
        array[i], array[m] = array[m], array[i]
    return array

# Сортировка вставкой
# Проходим по элементам списка, двигая все предыдущие элементы, которые больше текущего элемента вправо
# После чего переносим текущий элемент в подходящую для него позицию
# Лучшее время - n, среднее время - n^2, худшее время - n^2

def insertion_sort(array):
    for i in range(1, len(array)):
        key = array[i]
        j = i - 1
        while j >= 0 and key < array[j] :
            array[j+1] = array[j]
            j -= 1
        array[j+1] = key 
    return array

# Сортировка обменом (пузырьком)
# Проходим по списку множество раз, меняя попарно элементы в зависимости от их значений
# Лучшее время - n, среднее время - n^2, худшее время - n^2

def bubble_sort(array):
    for i in range(len(array) - 1):
        for j in range(len(array) - i - 1):
            if array[j] > array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]
    return array

# Сортировка Шелла
# Сортируем элементы на некотором расстоянии (шаге) друг от друга. После чего уменьшаем шаг
# Когда шаг станет равен единице произойдет обычная сортировка вставками
# Лучшее время - nlog^2n, среднее время - зависит от длин шагов, худшее время - n^2

def shell_sort(array):
    step = len(array)//2
    while step > 0:
        for i in range(step, len(array), 1):
            j = i
            delta = j - step
            while delta >= 0 and array[delta] > array[j]:
                array[delta], array[j] = array[j], array[delta]
                j = delta
                delta = j - step
        step //= 2
    return array

# Турнирная сортировка
# Лучшее время - nlogn, среднее время - nlogn, худшее время - nlogn

def tourney_sort(array):
    sorted_array = []
    pq = PriorityQueue()
    for i, num in enumerate(array):
        pq.put(num)
    while not pq.empty():
        sorted_array.append(pq.get()) 
    return sorted_array

# Быстрая сортировка
# Из списка выбираем случайный опорный элемент
# Разбиваем список на 3 списка (список элементов больших, меньших и равных опорному)
# Для списков больших и меньших чисел повторить сортировку рекурсивно
# Лучшее время - nlogn, среднее время - nlogn, худшее время - n^2

def quick_sort(array):
    if len(array) <= 1:
        return array
    else:
        q = random.choice(array)
        smaller_array = []
        bigger_array = []
        equal_array = []
        for n in array:
            if n < q:
                smaller_array.append(n)
            elif n > q:
                bigger_array.append(n)
            else:
                equal_array.append(n)
        return quick_sort(smaller_array) + equal_array + quick_sort(bigger_array)

# Пирамидальная сортировка
# Лучшее время - nlogn, среднее время - nlogn, худшее время - nlogn

# Процедура преобразования в двоичную кучу с корневым узлом i
def heapify(array, array_length, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2
# Существует ли левый дочерний элемент больший корня
    if l < array_length and array[i] < array[l]:
        largest = l
# Существует ли правый дочерний элемент больший корня
    if r < array_length and array[largest] < array[r]:
        largest = r
# Заменяем корень, если нужно
    if largest != i:
        array[i],array[largest] = array[largest],array[i]
        heapify(array, array_length, largest)

# Основная функция сортировки
def heap_sort(array):
# Строим кучу
    for i in range(len(array), -1, -1):
        heapify(array, len(array), i)
# Извлекаем элементы по одному
    for i in range(len(array) - 1, 0, -1):
        array[i], array[0] = array[0], array[i]
        heapify(array, i, 0)
    return array


m = int(input() or "50")
n = int(input() or "50")
min_limit = int(input() or "-250")
max_limit = int(input() or "1006")

new_array1 = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
    print(sel_sort(new_array1[i]))
print("\n")
    
new_array2 = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
    print(insertion_sort(new_array2[i]))
print("\n")

new_array3 = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
    print(bubble_sort(new_array3[i]))
print("\n")

new_array4 = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
    print(shell_sort(new_array4[i]))
print("\n")

new_array5 = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
    print(tourney_sort(new_array5[i]))
print("\n")

new_array6 = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
    print(quick_sort(new_array6[i]))
print("\n"), 1

new_array7 = [[random.randint(min_limit, max_limit) for row in range(0,n)] for row in range(0,m)]
for i in range(m):
    print(heap_sort(new_array7[i]))
print("\n")
# Out:
# 5
# 5
# -50
# 50
# [-43, -33, -1, 27, 38]
# [-38, -33, -28, 5, 32]
# [-27, -12, -2, 1, 11]
# [-49, -5, 3, 4, 20]
# [4, 6, 21, 26, 41]
#
#
# [-37, -21, 2, 3, 4]
# [-39, -3, 2, 28, 47]
# [-44, -38, -28, -16, 15]
# [-42, 4, 11, 27, 36]
# [-48, -33, -11, -5, -3]
#
#
# [-12, 20, 42, 42, 43]
# [-6, -3, 18, 20, 49]
# [-35, -15, -3, 3, 48]
# [-11, -11, -10, 5, 25]
# [-32, -21, 26, 29, 33]
#
#
# [-42, -14, -5, 6, 39]
# [-28, -4, 8, 29, 48]
# [-40, -21, 0, 4, 6]
# [-46, -33, -19, -4, 20]
# [-36, 12, 34, 34, 45]
#
#
# [-42, -35, -29, 40, 43]
# [-17, -2, -2, 16, 39]
# [-49, -40, -26, 11, 26]
# [-50, -9, -6, 45, 48]
# [-44, -42, -41, -26, -9]
#
#
# [-50, -47, -26, -12, 40]
# [-39, 11, 17, 26, 35]
# [-50, -33, -25, 1, 16]
# [-50, -38, -29, -19, 34]
# [1, 10, 23, 25, 28]
#
#
# [-49, -39, -39, -18, -5]
# [-26, -8, 7, 15, 24]
# [-18, -14, 2, 18, 46]
# [-19, -7, -2, 11, 16]
# [-48, -34, -32, 7, 43]

# %% [markdown]
# ## Вывод
# В результате данной работы были изучены различные алгоритмы сортировки
